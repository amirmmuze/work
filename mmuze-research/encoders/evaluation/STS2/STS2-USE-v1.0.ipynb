# %%
from pymongo import MongoClient
from sshtunnel import SSHTunnelForwarder
import pprint
from bson.objectid import ObjectId
import pyperclip as clip
import json
import tensorflow as tf
import pandas as pd
import numpy as np
import itertools as it
from functools import partial
# from datasu import auc
# import pixiedust
# clip.copy(json.dumps(m1['msg']))
import sys
# sys.path.append("..")
from random import shuffle
import nbimporter
# from nbimporter import NotebookLoader
# loader = NotebookLoader("..")


pd.options.mode.chained_assignment = None  # default='warn'


# from angie.service.app_config import AppConfig
from angie.service.managers.msg_similarity_manager import MsgSimilarityManager
from angie.service.managers.genie_msg_manager import GenieMsgManager
from angie.datacontracts.msg_similarity import SimilarityMeasure
from angie.libs.tensorflow_utils import sim_exact

# %%
def get_random_messages(n, rpr_key):
    fltr = {'rpr_key':rpr_key}
    embs_len = db.genie_conversation_messages_embs.find(fltr).count();
    random_ints = np.random.randint(0,embs_len, n)
    msgs_embs = []
    for r_ind in random_ints.tolist():
        rnd_msg_emb = list(db.genie_conversation_messages_embs.find(fltr).skip(r_ind).limit(1))[0];
        msgs_embs.append(rnd_msg_emb)

    msg_ids = map(lambda ms: ms['genie_conversation_message_id'], msgs_embs)
    msgs = gniMsgManager.get_messages_by_ids(msg_ids)

    random_msg_vectors = [{'text': msg.get_text(), 'vector': np.array(msg_emb['msg_vector'])} for msg_emb, msg in zip(msgs_embs, msgs)]   
    
    return random_msg_vectors

# %%
def get_cands_for_query(rpr_key, row):
    
#     import pdb; pdb.set_trace()
    
    K = 10
    query_vector = np.array(row['q_vector'])
    query = row['query']
    if 'genie_conversation_message_id' in row:
        query_mess_id = row['genie_conversation_message_id']
        sims = msgSimManager.get_top_k_similar_msgs_for_msg(query_mess_id, K*100, rpr_key, SimilarityMeasure.ANGDIST, chunk_size=500000)
    else:                
        sims = msgSimManager.get_top_k_similar_msgs_for_text(query, K*100, rpr_key, SimilarityMeasure.ANGDIST, chunk_size=500000)        
    
    sims_ids = list(map(lambda ms: ms.genie_msg_id, sims))
    sim_msgs = gniMsgManager.get_messages_by_ids(sims_ids)        
    sim_msgs_texts = [{'query': query, 'text': msg.get_text().strip(), 'sim_score': sim.similarity_score, 'is_random':False}  for sim, msg in zip(sims, sim_msgs)]
    
    sim_msgs_texts_unique = list({sm['text']:sm for sm in sim_msgs_texts}.values())    
    sim_msgs_texts_K = sorted(filter(lambda sm: sm['text'] != query, sim_msgs_texts_unique), key=lambda sm: sm['sim_score'], reverse=True)[0:K]
    
    rnd_msg_vectors = get_random_messages(K, rpr_key)    
    rnd_vectors= list(map(lambda m_v: m_v['vector'], rnd_msg_vectors))     
    query_rnd_sims = sim_exact([query_vector] ,rnd_vectors)[0].squeeze()
    rnd_msgs_texts = [{'query': query, 'text': msg['text'], 'sim_score': similarity_score, 'is_random':True} for similarity_score, msg in zip(query_rnd_sims, rnd_msg_vectors)]
    
    all_cand_msgs = sim_msgs_texts_K+rnd_msgs_texts    
    shuffle(all_cand_msgs)
    return all_cand_msgs

# %%
path = '/Users/sasha/temp/STS2'

# encoder_name = 'BERT'
# rpr_key = 'text_bert_1'
# from angie.libs.embed.embedding_model_wrapper_bert import BertEmbeddingModelWrapper
# encoder = BertEmbeddingModelWrapper()

encoder_name = 'USE'
rpr_key = 'text_use_1'
from angie.libs.embed.embedding_model_wrapper_use import UseEmbeddingModelWrapper
encoder = UseEmbeddingModelWrapper()

# %%
# MONGO_HOST = 'ec2-52-23-187-115.compute-1.amazonaws.com'
# MONGO_DB = "marketpulzz"
# server = SSHTunnelForwarder(
#     MONGO_HOST,
#     ssh_username='ubuntu',
#     ssh_pkey="/Users/sasha/.ssh/mmuze.pem",
# #     ssh_private_key_password="secret",
#     remote_bind_address=('127.0.0.1', 27017),
#     local_bind_address=('127.0.0.1', 63329),
#     set_keepalive = 5,
# )

# server.start()
# client = MongoClient('127.0.0.1', server.local_bind_port) # server.local_bind_port is assigned local port
# db = client[MONGO_DB]

# %%
MONGO_DB = "marketpulzz"
client = MongoClient('127.0.0.1', 27017)

# read_preference = ReadPreference.PRIMARY
# mongo_hosts : ["ec2-52-23-187-115.compute-1.amazonaws.com:27017", "ec2-52-90-96-8.compute-1.amazonaws.com:27017"]
# client = MongoClient(mongo_hosts, read_preference = read_preference)

db = client[MONGO_DB]

# %%
msgSimManager = MsgSimilarityManager(db)
gniMsgManager = GenieMsgManager(db)

# %%
query_input_path = f'{path}/STS2_queries.xlsx'
output_path = f'{path}/STS2_{encoder_name}-v1.0.xlsx'
df_queries = pd.read_excel(query_input_path)

# %%
df_queries['q_vector'] = encoder.embed(df_queries['query'].tolist()).tolist()

# %%
sts2_rows_lists = df_queries.apply(partial(get_cands_for_query, rpr_key), axis=1)
sts2_rows =list(it.chain(*sts2_rows_lists))
# Out:
# /usr/local/opt/pyenv/versions/anaconda3-5.3.1/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: count is deprecated. Use Collection.count_documents instead.
#   This is separate from the ipykernel package so we can avoid doing imports until
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-24-5ddd9bb48a74> in <module>()
# ----> 1 sts2_rows_lists = df_queries.apply(partial(get_cands_for_query, rpr_key), axis=1)
#       2 sts2_rows =list(it.chain(*sts2_rows_lists))
#
# /usr/local/opt/pyenv/versions/anaconda3-5.3.1/lib/python3.7/site-packages/pandas/core/frame.py in apply(self, func, axis, broadcast, raw, reduce, result_type, args, **kwds)
#    6012                          args=args,
#    6013                          kwds=kwds)
# -> 6014         return op.get_result()
#    6015
#    6016     def applymap(self, func):
#
# /usr/local/opt/pyenv/versions/anaconda3-5.3.1/lib/python3.7/site-packages/pandas/core/apply.py in get_result(self)
#     140             return self.apply_raw()
#     141
# --> 142         return self.apply_standard()
#     143
#     144     def apply_empty_result(self):
#
# /usr/local/opt/pyenv/versions/anaconda3-5.3.1/lib/python3.7/site-packages/pandas/core/apply.py in apply_standard(self)
#     246
#     247         # compute the result using the series generator
# --> 248         self.apply_series_generator()
#     249
#     250         # wrap results
#
# /usr/local/opt/pyenv/versions/anaconda3-5.3.1/lib/python3.7/site-packages/pandas/core/apply.py in apply_series_generator(self)
#     275             try:
#     276                 for i, v in enumerate(series_gen):
# --> 277                     results[i] = self.f(v)
#     278                     keys.append(v.name)
#     279             except Exception as e:
#
# <ipython-input-15-4ffa0038975c> in get_cands_for_query(rpr_key, row)
#       8     if 'genie_conversation_message_id' in row:
#       9         query_mess_id = row['genie_conversation_message_id']
# ---> 10         sims = msgSimManager.get_top_k_similar_msgs_for_msg(query_mess_id, K*100, rpr_key, SimilarityMeasure.ANGDIST, chunk_size=500000)
#      11     else:
#      12         sims = msgSimManager.get_top_k_similar_msgs_for_text(query, K*100, rpr_key, SimilarityMeasure.ANGDIST, chunk_size=500000)
#
# ~/dev/mmuze/marketpulzz/angie/angie/service/managers/msg_similarity_manager.py in get_top_k_similar_msgs_for_msg(self, genie_id, K, rpr_key, sim_measure, messages_filter, chunk_size)
#      52             msg_rpr = self.get_emb_repres_for_messages([genie_msg], rpr_key)[0]
#      53             # k_sims_all = self.get_top_k_similar_msgs_for_query_vector(msg_rpr.msg_vector, K + 1, rpr_key, sim_measure, messages_filter=messages_filter, chunk_size=chunk_size)
# ---> 54             k_sims_all = run_until_complete(self.get_top_k_similar_msgs_for_query_vector_async(msg_rpr.msg_vector, K + 1, rpr_key, sim_measure, messages_filter=messages_filter, chunk_size=chunk_size))
#      55             k_sims = list(filter(lambda ms: ms.genie_msg_id != genie_id, k_sims_all))
#      56             return k_sims
#
# ~/dev/mmuze/marketpulzz/angie/angie/service/extensions/asyncio_helper.py in run_until_complete(future)
#      12
#      13 def run_until_complete(future):
# ---> 14     return get_set_event_loop().run_until_complete(future)
#
# /usr/local/opt/pyenv/versions/anaconda3-5.3.1/lib/python3.7/asyncio/base_events.py in run_until_complete(self, future)
#     553         future.add_done_callback(_run_until_complete_cb)
#     554         try:
# --> 555             self.run_forever()
#     556         except:
#     557             if new_task and future.done() and not future.cancelled():
#
# /usr/local/opt/pyenv/versions/anaconda3-5.3.1/lib/python3.7/asyncio/base_events.py in run_forever(self)
#     508         self._check_closed()
#     509         if self.is_running():
# --> 510             raise RuntimeError('This event loop is already running')
#     511         if events._get_running_loop() is not None:
#     512             raise RuntimeError(
#
# RuntimeError: ('This event loop is already running', 'occurred at index 7')

# %%
df_sts2 = pd.DataFrame(sts2_rows)
df_sts2.to_excel(output_path)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-fa752575fa1b> in <module>()
# ----> 1 df_sts2 = pd.DataFrame(sts2_rows)
#       2 df_sts2.to_excel(output_path)
#
# NameError: name 'sts2_rows' is not defined

# %%
df_sts2
# Out:
#      is_random                                              query  sim_score  \
# 0         True  Hi, for some reason I'm unable to connect to t...   0.254696
# 1         True  Hi, for some reason I'm unable to connect to t...   0.273938
# 2         True  Hi, for some reason I'm unable to connect to t...   0.212945
# 3         True  Hi, for some reason I'm unable to connect to t...   0.400001
# 4         True  Hi, for some reason I'm unable to connect to t...   0.268851
# 5         True  Hi, for some reason I'm unable to connect to t...   0.307505
# 6         True  Hi, for some reason I'm unable to connect to t...   0.367030
# 7         True  Hi, for some reason I'm unable to connect to t...   0.344401
# 8         True  Hi, for some reason I'm unable to connect to t...   0.022898
# 9         True  Hi, for some reason I'm unable to connect to t...   0.275996
# 10        True  Hello! I need some advice on how to deal with ...   0.384308
# 11        True  Hello! I need some advice on how to deal with ...   0.226702
# 12        True  Hello! I need some advice on how to deal with ...   0.227865
# 13        True  Hello! I need some advice on how to deal with ...   0.328867
# 14        True  Hello! I need some advice on how to deal with ...   0.212080
# 15        True  Hello! I need some advice on how to deal with ...   0.337067
# 16        True  Hello! I need some advice on how to deal with ...   0.084105
# 17        True  Hello! I need some advice on how to deal with ...   0.264207
# 18        True  Hello! I need some advice on how to deal with ...   0.354055
# 19        True  Hello! I need some advice on how to deal with ...   0.295867
# 20        True  Custom repair moisturizer is to care more agin...   0.166416
# 21        True  Custom repair moisturizer is to care more agin...   0.358992
# 22        True  Custom repair moisturizer is to care more agin...   0.254455
# 23        True  Custom repair moisturizer is to care more agin...   0.274709
# 24        True  Custom repair moisturizer is to care more agin...   0.228424
# 25        True  Custom repair moisturizer is to care more agin...   0.001978
# 26        True  Custom repair moisturizer is to care more agin...   0.259200
# 27        True  Custom repair moisturizer is to care more agin...   0.266592
# 28        True  Custom repair moisturizer is to care more agin...   0.190122
# 29        True  Custom repair moisturizer is to care more agin...   0.183332
# ..         ...                                                ...        ...
# 90        True  Your cc cream used to come in very fair but I ...   0.028724
# 91        True  Your cc cream used to come in very fair but I ...   0.236178
# 92        True  Your cc cream used to come in very fair but I ...   0.326446
# 93        True  Your cc cream used to come in very fair but I ...   0.252797
# 94        True  Your cc cream used to come in very fair but I ...   0.366943
# 95        True  Your cc cream used to come in very fair but I ...   0.198886
# 96        True  Your cc cream used to come in very fair but I ...   0.208645
# 97        True  Your cc cream used to come in very fair but I ...   0.301179
# 98        True  Your cc cream used to come in very fair but I ...   0.339083
# 99        True  Your cc cream used to come in very fair but I ...   0.405669
# 100       True                   what is new for original penguin   0.178905
# 101      False                   what is new for original penguin   0.277159
# 102       True                   what is new for original penguin   0.133693
# 103      False                   what is new for original penguin   0.278810
# 104       True                   what is new for original penguin   0.128662
# 105      False                   what is new for original penguin   0.297071
# 106       True                   what is new for original penguin   0.216020
# 107       True                   what is new for original penguin   0.191378
# 108      False                   what is new for original penguin   0.321749
# 109      False                   what is new for original penguin   0.280315
# 110       True                   what is new for original penguin   0.255050
# 111       True                   what is new for original penguin   0.225143
# 112       True                   what is new for original penguin   0.150539
# 113      False                   what is new for original penguin   0.305536
# 114       True                   what is new for original penguin   0.228046
# 115      False                   what is new for original penguin   0.281807
# 116      False                   what is new for original penguin   0.292466
# 117      False                   what is new for original penguin   0.283959
# 118       True                   what is new for original penguin   0.096783
# 119      False                   what is new for original penguin   0.277976
#
#                                                   text
# 0    Great! Thats also a reason I was interested in...
# 1    Ok thank you. I also looked at the Clinique sm...
# 2                    I need something for dark circles
# 3    Hola quisiera saber por curl compa√±√≠a haven ...
# 4    so I have found out that the sonic system for ...
# 5                          What is my tracking number?
# 6          I need some help with my skin at the moment
# 7    I’m trying to change my Beaty appointment with...
# 8    i ordered a necklace over a week ago and it ha...
# 9    and are you still doing any offers on the buff...
# 10   Hello would it be possible to be sent some sma...
# 11   I was previously using superdefense day & nigh...
# 12          what other dar colors dresses do you have?
# 13            Hello do you sell anti aging foundation?
# 14        I recently purchased the 3 step kit number 3
# 15   Hello here. I‚Äôm trying to find out if there ...
# 16                                    My name is helen
# 17   I wanted to know regarding the status of an order
# 18   Okay. Will they send me a tracking number when...
# 19   hi i wanted to ask because i purchased this pr...
# 20                                          No thank u
# 21   Given my skin tone what one should I go for ? ...
# 22   Hello, I'm a midwife holding a fundraising Chr...
# 23   Hi Dawn, ..please could you let me know if Cli...
# 24   Thank you for replying to us here at Clinique ...
# 25   So to process the refund would I have to phone...
# 26   can you let me know where i can order one from...
# 27   I'm having a bit of problem finding the founda...
# 28   Hi Jennifer, my 15year old daughter recently p...
# 29   I have eczema & my skin lately on my face espe...
# ..                                                 ...
# 90   Hi I was just wondering if you could advise me...
# 91             There was a problem placing your order.
# 92   Hi, is clarifying lotion 3 good for combinatio...
# 93   Hi, could you tell me does the sonic brush rem...
# 94    Yay! Thank you! Will there be a tracking number?
# 95   Hello I just want to know why my order is taki...
# 96        Fabulous . Thank you for your help. Good bye
# 97                 Is this not the customer care team?
# 98   Hi I have been trying for months to get hold o...
# 99   Are will eligiable for a refund as the branch ...
# 100  Ok, so would i then be able to go in store and...
# 101  Hi please can you tell me when the all about e...
# 102  I would like to track my order stays since I h...
# 103  Hi I use beyond perfecting foundation and I us...
# 104  Hi I ordered 3shorts in uspolo website how sho...
# 105                          what about new high boots
# 106         I am having a problem with return an order
# 107  Dawn, I am sorry but a friend has just arrived...
# 108             what new dresses do you have for fall?
# 109  is it because this is the colours suited to mo...
# 110                        Go back to cleanser options
# 111  Do you still sell the ‚Äòalmost bronzer‚Äù spf...
# 112                                        more fabric
# 113                  How can I follow for the tracking
# 114  Hello, I recently bought a clinge mascara and ...
# 115  Hi Dawn. why cant I purchase a natural glossy ...
# 116           I was bought smart night what’s this for
# 117  No the CN 58 is fine I have not tried the glow...
# 118  hi me again just a question if iorder the stuf...
# 119  Hi Sam. is Quickliner for Eyes Intense out of ...
#
# [120 rows x 4 columns]

# %%
df_sts2
